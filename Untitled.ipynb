# %%
import pandas as pd

# %%
from facebook_scraper import get_posts

url = []
text = []
date = []
comments = []
likes = []
user = []

interests = ['סנטר','צפון ישן','הצפון הישן','שלושה חדרים','3 חדרים','שני שותפים','2 שותפים','בוגרשוב','כיכר','לב העיר','רבין', 'פרישמן','גורדון']
ignore = ['מכירה','למכירה']

groupNames = ['287564448778602','telavivrentals','ApartmentsTelAviv'
             ,'458499457501175','2092819334342645','1196843027043598'
             ,'733810383372996','485208978351445']

for i in groupNames:
    for post in get_posts(group=i, pages=6 ,options={"posts_per_page": 50, "allow_extra_requests": False}):
        if any(words in post['post_text'] for words in interests):
            if any(words in post['post_text'] for words in ignore):
                continue
            text.append(post['post_text'][:200])
            url.append(post['post_url'])
            date.append(post['time'])
            comments.append(post['comments'])
            likes.append(post['likes'])
            user.append(post['username'])


data = {
    'date': date,
    'link': url,
    'info': text,
    'username': user,
    '#comments': comments,
    '#likes': likes
}


df = pd.DataFrame.from_dict(data, orient='index')
df = df.transpose()
df
# Out:
#                    date                                               link  \
# 0   2022-06-24 12:44:50  https://m.facebook.com/groups/287564448778602/...
# 1   2022-06-25 12:50:46  https://m.facebook.com/groups/287564448778602/...
# 2   2022-06-25 14:07:19  https://m.facebook.com/groups/287564448778602/...
# 3   2022-06-22 12:05:04  https://m.facebook.com/groups/287564448778602/...
# 4   2022-06-25 13:40:26  https://m.facebook.com/groups/287564448778602/...
# ..                  ...                                                ...
# 324 2022-06-21 14:48:32  https://m.facebook.com/groups/485208978351445/...
# 325 2022-06-21 12:38:40  https://m.facebook.com/groups/485208978351445/...
# 326 2022-06-21 12:31:55  https://m.facebook.com/groups/485208978351445/...
# 327 2022-06-21 09:09:23  https://m.facebook.com/groups/485208978351445/...
# 328 2022-06-20 17:49:40  https://m.facebook.com/groups/485208978351445/...
#
#                                                   info           username  \
# 0    מפנים דירה מדהימה בצפון הישן (רחוב בני משה) 🏠\...      Yana Kourskoi
# 1    אני ועמית מחפשים שותפה לדירה המדהימה שלנו ברחו...   Daniel Aranovich
# 2    שקלים נדל"ן מציגים :\nמבחר דירות יוקרה חדשות מ...        שקלים נדל"ן
# 3    ניתן לבקר היום בתיאום מראש*******************\...  Ruthy Ish- Cassit
# 4    סבלט בתל אביב!!\n3.7-1.8\nרחוב בזל המדהים על ד...        Mia Winraob
# ..                                                 ...                ...
# 324  בצפון הישן ליד בזל\nדירת 3 חדרים גדולה\nמשופצת...   Shimrit Turgeman
# 325  להשכרה\nבתל אביב יפו - הצפון החדש - כיכר המדינ...       Tal Boshtein
# 326  להשכרה\nבתל אביב יפו - צמרות איילון, פארק צמרת...   Avichai Avrahami
# 327  להשכרה\nבתל אביב יפו - הצפון החדש - כיכר המדינ...          Or Shaham
# 328  להשכרה\nבתל אביב יפו - הצפון הישן - דרום\nדירת...      Ornella Avnat
#
#     #comments #likes
# 0          12      3
# 1           4      1
# 2           0      0
# 3           1      0
# 4           0      0
# ..        ...    ...
# 324         0      0
# 325         0      0
# 326         0      0
# 327         0      0
# 328         0      0
#
# [329 rows x 6 columns]

# %%
from datetime import datetime, timedelta
today = pd.to_datetime(datetime.now())
threeDaysAgo =  pd.to_datetime(datetime.today() - timedelta(days=3))
df = df.loc[(df['date']>threeDaysAgo) & (df['date']<datetime.now())]
df = df.sort_values('date',ascending=False)
df.dropna
df.drop_duplicates(subset = 'info')
df
# Out:
#                    date                                               link  \
# 283 2022-06-25 14:28:38  https://m.facebook.com/groups/733810383372996/...
# 2   2022-06-25 14:07:19  https://m.facebook.com/groups/287564448778602/...
# 50  2022-06-25 14:06:49  https://m.facebook.com/groups/telavivrentals/p...
# 51  2022-06-25 14:04:52  https://m.facebook.com/groups/telavivrentals/p...
# 4   2022-06-25 13:40:26  https://m.facebook.com/groups/287564448778602/...
# ..                  ...                                                ...
# 28  2022-06-22 15:40:24  https://m.facebook.com/groups/287564448778602/...
# 92  2022-06-22 15:34:05  https://m.facebook.com/groups/1614176462140511...
# 229 2022-06-22 15:31:43  https://m.facebook.com/groups/2092819334342645...
# 186 2022-06-22 15:03:40  https://m.facebook.com/groups/458499457501175/...
# 93  2022-06-22 15:02:53  https://m.facebook.com/groups/telavivrentals/p...
#
#                                                   info        username  \
# 283  4 חדרים ענקית ל-3 שותפים בקרבת כיכר רבין + מרפ...          Ben Sh
# 2    שקלים נדל"ן מציגים :\nמבחר דירות יוקרה חדשות מ...     שקלים נדל"ן
# 50   שקלים נדל"ן מציגים :\nמבחר דירות יוקרה חדשות מ...     שקלים נדל"ן
# 51   שקלים נדל"ן מציגים :\nדופלקס פרימיום להשכרה בכ...      Or Shkalim
# 4    סבלט בתל אביב!!\n3.7-1.8\nרחוב בזל המדהים על ד...     Mia Winraob
# ..                                                 ...             ...
# 28   מציעים את הדירה שלנו להחלפה🤍\n\nדירת 2 חדרים, ...  Ayala Shegolev
# 92   דירה מתיווך\n🔷בפריים לוקיישן ברחוב ז'בוטינסקי ...       Nir Cohen
# 229  להשכרה דירת 2 חדרים בתל אביב, ברחוב מלכי ישראל...  Daniel Shushan
# 186  ⭐⭐להשכרה מרוקח נכסים⭐⭐\n🏠דירת 3 חדרים ל2 שותפי...     Yaron Rokah
# 93   ⭐⭐להשכרה מרוקח נכסים⭐⭐\n🏠דירת 3 חדרים ל2 שותפי...     Yaron Rokah
#
#     #comments #likes
# 283         0      0
# 2           0      0
# 50          0      0
# 51          0      0
# 4           0      0
# ..        ...    ...
# 28         12      3
# 92          0      0
# 229         2      1
# 186         0      0
# 93          0      0
#
# [141 rows x 6 columns]

# %%
df.to_csv('./results.csv',index=False, encoding = 'utf-8-sig')
